# %% [markdown]
# # WASDE Data Exploration

# %% [markdown]
# 1. Libraries and setup

# %%
# -- Setup environment and imports --

# Add 'src' directory to path to import project modules
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / "src"))

# Load environment variables securely (e.g., WASDE_JWT)
from dotenv import load_dotenv
import os
load_dotenv()
my_token = os.getenv("WASDE_JWT")

# Core imports
from datetime import datetime
import pandas as pd
import os

# Project configuration and functions
from config import (
    WASDE_FOLDER,
    WHEAT,
    WHEAT_CURRENT,
    WHEAT_NEXT,
    WHEAT_OUTLOOK,
    CORN,
    CORN_CURRENT,
    CORN_NEXT,
    CORN_OUTLOOK,
    SOYBEAN,
    SOYBEAN_CURRENT,
    SOYBEAN_NEXT,
    SOYBEAN_OUTLOOK,
    SOYBEAN_OIL,
    SOYBEAN_OIL_CURRENT,
    SOYBEAN_OIL_NEXT,
    SOYBEAN_OIL_OUTLOOK,
    SOYBEAN_MEAL,
    SOYBEAN_MEAL_CURRENT,
    SOYBEAN_MEAL_NEXT,
    SOYBEAN_MEAL_OUTLOOK,
    COMMODITY
)

from wasde_functions import (
    fetch_wasde_releases, 
    download_release_files,
    process_wheat,
    process_corn,
    process_soybean,
    process_soybean_oil,
    process_soybean_meal   
)

# %% [markdown]
# 2. Identifying reports available and download of the csv/xml files

# %%
# Step 1: Fetch WASDE releases metadata using your secure token
releases = fetch_wasde_releases(token=my_token)
print(f"{len(releases)} releases found.")

# Step 2: Download the XML files (limit optional for testing)
download_release_files(releases, limit=None)
# Out:
# 317 releases found.
# Downloaded: 2025-06-12_wasde0625.xls
# Already exists: 2025-05-12_wasde0525v2.xls, skipping.
# Already exists: 2025-04-10_wasde0425v2.xls, skipping.
# Already exists: 2025-03-11_wasde0325.xls, skipping.
# Already exists: 2025-02-11_wasde0225.xls, skipping.
# Already exists: 2025-01-10_wasde0125.xls, skipping.
# Already exists: 2024-12-10_wasde1224v2.xls, skipping.
# Already exists: 2024-11-08_wasde1124.xls, skipping.
# Already exists: 2024-10-11_wasde1024.xls, skipping.
# Already exists: 2024-09-12_wasde0924.xls, skipping.
# Already exists: 2024-08-12_wasde0824.xls, skipping.
# Already exists: 2024-07-12_wasde0724.xls, skipping.
# Already exists: 2024-06-12_wasde0624.xls, skipping.
# Already exists: 2024-05-10_wasde0524.xls, skipping.
# Already exists: 2024-04-11_wasde0424.xls, skipping.
# Already exists: 2024-03-08_wasde0324.xls, skipping.
# Already exists: 2024-02-08_wasde0224.xls, skipping.
# Already exists: 2024-01-12_wasde0124.xls, skipping.
# Already exists: 2023-12-08_wasde1223.xls, skipping.
# Already exists: 2023-11-09_wasde1123.xls, skipping.
# Already exists: 2023-10-12_wasde1023.xls, skipping.
# Already exists: 2023-09-12_wasde0923.xls, skipping.
# Already exists: 2023-08-11_wasde0823.xls, skipping.
# Already exists: 2023-07-12_wasde0723.xls, skipping.
# Already exists: 2023-06-09_wasde0623.xls, skipping.
# Already exists: 2023-05-12_wasde0523.xls, skipping.
# Already exists: 2023-04-11_wasde0423.xls, skipping.
# Already exists: 2023-03-08_wasde0323.xls, skipping.
# Already exists: 2023-02-08_wasde0223.xls, skipping.
# Already exists: 2023-01-12_wasde0123.xls, skipping.
# Already exists: 2022-12-09_wasde1222.xls, skipping.
# Already exists: 2022-11-09_wasde1122.xls, skipping.
# Already exists: 2022-10-12_wasde1022.xls, skipping.
# Already exists: 2022-09-12_wasde0922.xls, skipping.
# Already exists: 2022-08-12_wasde0822.xls, skipping.
# Already exists: 2022-07-12_wasde0722.xls, skipping.
# Already exists: 2022-06-10_wasde0622.xls, skipping.
# Already exists: 2022-05-12_wasde0522.xls, skipping.
# Already exists: 2022-04-08_wasde0422.xls, skipping.
# Already exists: 2022-03-09_wasde0322.xls, skipping.
# Already exists: 2022-02-09_wasde0222.xls, skipping.
# Already exists: 2022-01-12_wasde0122.xls, skipping.
# Already exists: 2021-12-09_wasde1221.xls, skipping.
# Already exists: 2021-11-09_wasde1121.xls, skipping.
# Already exists: 2021-10-12_wasde1021.xls, skipping.
# Already exists: 2021-09-10_wasde0921.xls, skipping.
# Already exists: 2021-08-12_wasde0821.xls, skipping.
# Already exists: 2021-07-12_latest.xls, skipping.
# Already exists: 2021-06-10_latest.xls, skipping.
# Already exists: 2021-05-12_latest.xls, skipping.
# Already exists: 2021-04-09_latest.xls, skipping.
# Already exists: 2021-03-09_latest.xls, skipping.
# Already exists: 2021-02-09_latest.xls, skipping.
# Already exists: 2021-01-12_latest.xls, skipping.
# Already exists: 2020-12-10_latest.xls, skipping.
# Already exists: 2020-11-10_latest.xls, skipping.
# Already exists: 2020-10-09_latest.xls, skipping.
# Already exists: 2020-09-11_latest.xls, skipping.
# Already exists: 2020-08-12_latest.xls, skipping.
# Already exists: 2020-07-10_latest.xls, skipping.
# Already exists: 2020-06-11_latest.xls, skipping.
# Already exists: 2020-05-12_latest.xls, skipping.
# Already exists: 2020-04-09_latest.xls, skipping.
# Already exists: 2020-03-10_latest.xls, skipping.
# Already exists: 2020-02-11_latest.xls, skipping.
# Already exists: 2020-01-10_latest.xls, skipping.
# Already exists: 2019-12-10_latest.xls, skipping.
# Already exists: 2019-11-08_latest.xls, skipping.
# Already exists: 2019-11-08_latest.xls, skipping.
# Already exists: 2019-11-08_latest.xls, skipping.
# Already exists: 2019-10-10_latest.xls, skipping.
# Already exists: 2019-09-12_latest.xls, skipping.
# Already exists: 2019-08-12_latest.xls, skipping.
# Already exists: 2019-07-11_latest.xls, skipping.
# Already exists: 2019-06-11_latest.xls, skipping.
# Already exists: 2019-05-10_wasde0519.xls, skipping.
# Already exists: 2019-04-09_latest.xls, skipping.
# Already exists: 2019-03-08_latest.xls, skipping.
# Already exists: 2019-02-08_latest.xls, skipping.
# Already exists: 2018-12-14_latest.xls, skipping.
# Already exists: 2018-12-11_latest.xls, skipping.
# Already exists: 2018-11-08_latest.xls, skipping.
# Already exists: 2018-10-11_WASDE-582-October-11-2018.xls, skipping.
# Already exists: 2018-09-12_wasde-09-12-2018.xls, skipping.
# Already exists: 2018-08-10_wasde-08-10-2018.xls, skipping.
# Already exists: 2018-07-12_wasde-07-12-2018.xls, skipping.
# Already exists: 2018-06-12_wasde-06-12-2018.xls, skipping.
# Already exists: 2018-05-10_wasde-05-10-2018.xls, skipping.
# Already exists: 2018-04-10_wasde-04-10-2018.xls, skipping.
# Already exists: 2018-03-08_wasde-03-08-2018.xls, skipping.
# Already exists: 2018-02-08_wasde-02-08-2018.xls, skipping.
# Already exists: 2018-01-12_wasde-01-12-2018.xls, skipping.
# Already exists: 2017-12-12_wasde-12-12-2017.xls, skipping.
# Already exists: 2017-11-09_wasde-11-09-2017.xls, skipping.
# Already exists: 2017-10-12_wasde-10-12-2017.xls, skipping.
# Already exists: 2017-09-12_wasde-09-12-2017.xls, skipping.
# Already exists: 2017-08-10_wasde-08-10-2017.xls, skipping.
# Already exists: 2017-07-12_wasde-07-12-2017.xls, skipping.
# Already exists: 2017-06-09_wasde-06-09-2017.xls, skipping.
# Already exists: 2017-05-10_wasde-05-10-2017.xls, skipping.
# Already exists: 2017-04-11_wasde-04-11-2017.xls, skipping.
# Already exists: 2017-03-09_wasde-03-09-2017.xls, skipping.
# Already exists: 2017-02-09_wasde-02-09-2017.xls, skipping.
# Already exists: 2017-01-12_wasde-01-12-2017.xls, skipping.
# Already exists: 2016-12-09_wasde-12-09-2016.xls, skipping.
# Already exists: 2016-11-09_wasde-11-09-2016.xls, skipping.
# Already exists: 2016-10-12_wasde-10-12-2016.xls, skipping.
# Already exists: 2016-09-12_wasde-09-12-2016.xls, skipping.
# Already exists: 2016-08-12_wasde-08-12-2016.xls, skipping.
# Already exists: 2016-07-12_wasde-07-12-2016.xls, skipping.
# Already exists: 2016-06-10_wasde-06-10-2016.xls, skipping.
# Already exists: 2016-05-10_wasde-05-10-2016.xls, skipping.
# Already exists: 2016-04-12_wasde-04-12-2016.xls, skipping.
# Already exists: 2016-03-09_wasde-03-09-2016.xls, skipping.
# Already exists: 2016-02-09_wasde-02-09-2016.xls, skipping.
# Already exists: 2016-01-12_wasde-01-12-2016.xls, skipping.
# Already exists: 2015-12-09_wasde-12-09-2015.xls, skipping.
# Already exists: 2015-11-10_wasde-11-10-2015.xls, skipping.
# Already exists: 2015-10-09_wasde-10-09-2015.xls, skipping.
# Already exists: 2015-09-11_wasde-09-11-2015.xls, skipping.
# Already exists: 2015-08-12_wasde-08-12-2015.xls, skipping.
# Already exists: 2015-07-10_wasde-07-10-2015.xls, skipping.
# Already exists: 2015-06-10_wasde-06-10-2015.xls, skipping.
# Already exists: 2015-05-12_wasde-05-12-2015.xls, skipping.
# Already exists: 2015-04-09_wasde-04-09-2015.xls, skipping.
# Already exists: 2015-03-10_wasde-03-10-2015.xls, skipping.
# Already exists: 2015-02-10_wasde-02-10-2015.xls, skipping.
# Already exists: 2015-01-12_wasde-01-12-2015.xls, skipping.
# Already exists: 2014-12-10_wasde-12-10-2014.xls, skipping.
# Already exists: 2014-11-10_wasde-11-10-2014.xls, skipping.
# Already exists: 2014-10-10_wasde-10-10-2014.xls, skipping.
# Already exists: 2014-09-11_wasde-09-11-2014.xls, skipping.
# Already exists: 2014-08-12_wasde-08-12-2014.xls, skipping.
# Already exists: 2014-07-11_wasde-07-11-2014.xls, skipping.
# Already exists: 2014-06-11_wasde-06-11-2014.xls, skipping.
# Already exists: 2014-05-09_wasde-05-09-2014.xls, skipping.
# Already exists: 2014-04-09_wasde-04-09-2014.xls, skipping.
# Already exists: 2014-03-10_wasde-03-10-2014.xls, skipping.
# Already exists: 2014-02-10_wasde-02-10-2014.xls, skipping.
# Already exists: 2014-01-10_wasde-01-10-2014.xls, skipping.
# Already exists: 2013-12-10_wasde-12-10-2013.xls, skipping.
# Already exists: 2013-11-08_wasde-11-08-2013.xls, skipping.
# Already exists: 2013-09-12_wasde-09-12-2013.xls, skipping.
# Already exists: 2013-08-12_ORIGwasde-08-12-2013.xls, skipping.
# Already exists: 2013-08-12_wasde-08-12-2013.xls, skipping.
# Already exists: 2013-07-11_ORIGwasde-07-11-2013.xls, skipping.
# Already exists: 2013-07-11_R1wasde-07-11-2013.xls, skipping.
# Already exists: 2013-07-11_wasde-07-11-2013.xls, skipping.
# Already exists: 2013-06-12_wasde-06-12-2013.xls, skipping.
# Already exists: 2013-05-10_wasde-05-10-2013.xls, skipping.
# Already exists: 2013-04-10_wasde-04-10-2013.xls, skipping.
# Already exists: 2013-03-08_wasde-03-08-2013.xls, skipping.
# Already exists: 2013-02-08_wasde-02-08-2013.xls, skipping.
# Already exists: 2013-01-11_wasde-01-11-2013.xls, skipping.
# Already exists: 2012-12-11_wasde-12-11-2012.xls, skipping.
# Already exists: 2012-11-09_wasde-11-09-2012.xls, skipping.
# Already exists: 2012-10-11_wasde-10-11-2012.xls, skipping.
# Already exists: 2012-09-12_wasde-09-12-2012.xls, skipping.
# Already exists: 2012-08-10_wasde-08-10-2012.xls, skipping.
# Already exists: 2012-07-11_wasde-07-11-2012.xls, skipping.
# Already exists: 2012-06-12_wasde-06-12-2012.xls, skipping.
# Already exists: 2012-05-10_wasde-05-10-2012.xls, skipping.
# Already exists: 2012-04-10_wasde-04-10-2012.xls, skipping.
# Already exists: 2012-03-09_wasde-03-09-2012.xls, skipping.
# Already exists: 2012-02-09_wasde-02-09-2012.xls, skipping.
# Already exists: 2012-01-12_wasde-01-12-2012.xls, skipping.
# Already exists: 2011-12-09_wasde-12-09-2011.xls, skipping.
# Already exists: 2011-11-09_wasde-11-09-2011.xls, skipping.
# Already exists: 2011-10-12_wasde-10-12-2011.xls, skipping.
# Already exists: 2011-09-12_wasde-09-12-2011.xls, skipping.
# Already exists: 2011-08-11_wasde-08-11-2011.xls, skipping.
# Already exists: 2011-07-12_wasde-07-12-2011.xls, skipping.
# Already exists: 2011-06-09_wasde-06-09-2011.xls, skipping.
# Already exists: 2011-05-11_wasde-05-11-2011.xls, skipping.
# Already exists: 2011-04-08_wasde-04-08-2011.xls, skipping.
# Already exists: 2011-03-10_wasde-03-10-2011.xls, skipping.
# Already exists: 2011-02-09_wasde-02-09-2011.xls, skipping.
# Already exists: 2011-01-12_wasde-01-12-2011.xls, skipping.
# Already exists: 2010-12-10_wasde-12-10-2010.xls, skipping.
# Already exists: 2010-11-09_wasde-11-09-2010.xls, skipping.
# Already exists: 2010-10-08_wasde-10-08-2010.xls, skipping.
# Already exists: 2010-09-10_wasde-09-10-2010.xls, skipping.
# Already exists: 2010-08-12_wasde-08-12-2010.xls, skipping.
# Already exists: 2010-07-09_wasde-07-09-2010.xls, skipping.
# Already exists: 2008-05-09_wasde-05-09-2008_Historical_Broiler_revisions.xls, skipping.
# Already exists: 2008-05-09_wasde-05-09-2008_Historical_Dairy_revisions.xls, skipping.
# Already exists: 2004-05-12_wasde-05-12-2004_world_coarse_grains_revision.xls, skipping.
# Already exists: 2003-07-11_wasde-07-11-2003_EU_oilseed_revision.xls, skipping.
# Already exists: 2003-07-11_wasde-07-11-2003_world_oilseed_revision.xls, skipping.
# Already exists: 2002-11-12_wasde-11-12-2002_China_wheat_revision.xls, skipping.
# Already exists: 2002-05-10_wasde-05-10-2002_EUgrains_revision.xls, skipping.
# Already exists: 2002-05-10_wasde-05-10-2002_broilers_revision.xls, skipping.
# Already exists: 2002-05-10_wasde-05-10-2002_world_grains_revision.xls, skipping.
# Already exists: 2001-05-10_wasde-05-10-2001_wheat-revision.xls, skipping.
# Already exists: 2001-05-09_wasde-05-09-2001_rice-revision.xls, skipping.
# Already exists: 2001-05-09_wasde-05-09-2001_coursegrains-revision.xls, skipping.

# %% [markdown]
# 3. Processing wheat

# %%
files = list(WASDE_FOLDER.glob('*.xls'))

latest_file_by_date = {}
for file in files:
    basename = os.path.basename(file)
    report_date = basename.split('_')[0]
    latest_file_by_date[report_date] = file

dfs_wheat = []
dfs_current = []
dfs_next = []
dfs_outlook = []

for file in latest_file_by_date.values():
    result = process_wheat(file)
    if result is None:
        continue

    df_wheat, df_current, df_next, df_outlook = result
    dfs_wheat.append(df_wheat)
    dfs_current.append(df_current)
    dfs_next.append(df_next)
    dfs_outlook.append(df_outlook)

df_wheat = pd.concat(dfs_wheat, ignore_index=True)
df_wheat_current = pd.concat(dfs_current, ignore_index=True, sort=False)
df_wheat_next = pd.concat(dfs_next, ignore_index=True, sort=False)
df_wheat_outlook = pd.concat(dfs_outlook, ignore_index=True, sort=False)

df_wheat_current = df_wheat_current.reset_index(drop=True)
df_wheat_next = df_wheat_next.reset_index(drop=True)
df_wheat_outlook = df_wheat_outlook.reset_index(drop=True)
df_wheat = df_wheat.reset_index(drop=True)

df_wheat_current.to_excel(WHEAT_CURRENT)
df_wheat_next.to_excel(WHEAT_NEXT)
df_wheat_outlook.to_excel(WHEAT_OUTLOOK)
df_wheat.to_excel(WHEAT)

print(f"✅ df_wheat created with {len(df_wheat)} lines.")
print(f"✅ df_wheat_current created with {len(df_wheat_current)} lines.")
print(f"✅ df_wheat_next created with {len(df_wheat_next)} lines.")
print(f"✅ df_wheat_outlook created with {len(df_wheat_outlook)} lines.")
# Out:
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-09_wasde-05-09-2001_rice-revision.xls: Worksheet named 'Page 18' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-10_wasde-05-10-2001_wheat-revision.xls: Worksheet named 'Page 18' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-05-10_wasde-05-10-2002_world_grains_revision.xls: Worksheet named 'Page 18' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-11-12_wasde-11-12-2002_China_wheat_revision.xls: Worksheet named 'Page 18' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2003-07-11_wasde-07-11-2003_world_oilseed_revision.xls: Worksheet named 'Page 18' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2004-05-12_wasde-05-12-2004_world_coarse_grains_revision.xls: Worksheet named 'Page 18' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2008-05-09_wasde-05-09-2008_Historical_Dairy_revisions.xls: Worksheet named 'Page 18' not found
# ✅ df_wheat created with 11319 lines.
# ✅ df_wheat_current created with 179 lines.
# ✅ df_wheat_next created with 179 lines.
# ✅ df_wheat_outlook created with 179 lines.

# %% [markdown]
# 4. Processing corn

# %%
files = list(WASDE_FOLDER.glob('*.xls'))

latest_file_by_date = {}
for file in files:
    basename = os.path.basename(file)
    report_date = basename.split('_')[0]
    latest_file_by_date[report_date] = file

dfs_corn = []
dfs_current = []
dfs_next = []
dfs_outlook = []

for file in latest_file_by_date.values():
    result = process_corn(file)
    if result is None:
        continue

    df_corn, df_current, df_next, df_outlook = result
    dfs_corn.append(df_corn)
    dfs_current.append(df_current)
    dfs_next.append(df_next)
    dfs_outlook.append(df_outlook)

df_corn = pd.concat(dfs_corn, ignore_index=True)
df_corn_current = pd.concat(dfs_current, ignore_index=True, sort=False)
df_corn_next = pd.concat(dfs_next, ignore_index=True, sort=False)
df_corn_outlook = pd.concat(dfs_outlook, ignore_index=True, sort=False)

df_corn_current = df_corn_current.reset_index(drop=True)
df_corn_next = df_corn_next.reset_index(drop=True)
df_corn_outlook = df_corn_outlook.reset_index(drop=True)
df_corn = df_corn.reset_index(drop=True)

df_corn_current.to_excel(CORN_CURRENT)
df_corn_next.to_excel(CORN_NEXT)
df_corn_outlook.to_excel(CORN_OUTLOOK)
df_corn.to_excel(CORN)

print(f"✅ df_corn created with {len(df_corn)} lines.")
print(f"✅ df_corn_current created with {len(df_corn_current)} lines.")
print(f"✅ df_corn_next created with {len(df_corn_next)} lines.")
print(f"✅ df_corn_outlook created with {len(df_corn_outlook)} lines.")
# Out:
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-09_wasde-05-09-2001_rice-revision.xls: Worksheet named 'Page 22' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-10_wasde-05-10-2001_wheat-revision.xls: Worksheet named 'Page 22' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-05-10_wasde-05-10-2002_world_grains_revision.xls: Worksheet named 'Page 22' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-11-12_wasde-11-12-2002_China_wheat_revision.xls: Worksheet named 'Page 22' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2003-07-11_wasde-07-11-2003_world_oilseed_revision.xls: Worksheet named 'Page 22' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2004-05-12_wasde-05-12-2004_world_coarse_grains_revision.xls: Worksheet named 'Page 22' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2008-05-09_wasde-05-09-2008_Historical_Dairy_revisions.xls: Worksheet named 'Page 22' not found
# ✅ df_corn created with 9873 lines.
# ✅ df_corn_current created with 179 lines.
# ✅ df_corn_next created with 179 lines.
# ✅ df_corn_outlook created with 179 lines.

# %% [markdown]
# 5. Processing soybean

# %%
files = list(WASDE_FOLDER.glob('*.xls'))

latest_file_by_date = {}
for file in files:
    basename = os.path.basename(file)
    report_date = basename.split('_')[0]
    latest_file_by_date[report_date] = file

dfs_soybean = []
dfs_current = []
dfs_next = []
dfs_outlook = []

for file in latest_file_by_date.values():
    result = process_soybean(file)
    if result is None:
        continue

    df_soybean, df_current, df_next, df_outlook = result
    dfs_soybean.append(df_soybean)
    dfs_current.append(df_current)
    dfs_next.append(df_next)
    dfs_outlook.append(df_outlook)

df_soybean = pd.concat(dfs_soybean, ignore_index=True)
df_soybean_current = pd.concat(dfs_current, ignore_index=True, sort=False)
df_soybean_next = pd.concat(dfs_next, ignore_index=True, sort=False)
df_soybean_outlook = pd.concat(dfs_outlook, ignore_index=True, sort=False)

df_soybean_current = df_soybean_current.reset_index(drop=True)
df_soybean_next = df_soybean_next.reset_index(drop=True)
df_soybean_outlook = df_soybean_outlook.reset_index(drop=True)
df_soybean = df_soybean.reset_index(drop=True)

df_soybean_current.to_excel(SOYBEAN_CURRENT)
df_soybean_next.to_excel(SOYBEAN_NEXT)
df_soybean_outlook.to_excel(SOYBEAN_OUTLOOK)
df_soybean.to_excel(SOYBEAN)

print(f"✅ df_soybean created with {len(df_soybean)} lines.")
print(f"✅ df_soybean_current created with {len(df_soybean_current)} lines.")
print(f"✅ df_soybean_next created with {len(df_soybean_next)} lines.")
print(f"✅ df_soybean_outlook created with {len(df_soybean_outlook)} lines.")
# Out:
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-09_wasde-05-09-2001_rice-revision.xls: Worksheet named 'Page 28' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-10_wasde-05-10-2001_wheat-revision.xls: Worksheet named 'Page 28' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-05-10_wasde-05-10-2002_world_grains_revision.xls: Worksheet named 'Page 28' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-11-12_wasde-11-12-2002_China_wheat_revision.xls: Worksheet named 'Page 28' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2003-07-11_wasde-07-11-2003_world_oilseed_revision.xls: Worksheet named 'Page 28' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2004-05-12_wasde-05-12-2004_world_coarse_grains_revision.xls: Worksheet named 'Page 28' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2008-05-09_wasde-05-09-2008_Historical_Dairy_revisions.xls: Worksheet named 'Page 28' not found
# ✅ df_soybean created with 6674 lines.
# ✅ df_soybean_current created with 179 lines.
# ✅ df_soybean_next created with 179 lines.
# ✅ df_soybean_outlook created with 179 lines.

# %% [markdown]
# 6. Processing soybean oil

# %%
files = list(WASDE_FOLDER.glob('*.xls'))

latest_file_by_date = {}
for file in files:
    basename = os.path.basename(file)
    report_date = basename.split('_')[0]
    latest_file_by_date[report_date] = file

dfs_soybean_oil = []
dfs_current = []
dfs_next = []
dfs_outlook = []

for file in latest_file_by_date.values():
    result = process_soybean_oil(file)
    if result is None:
        continue

    df_soybean_oil, df_current, df_next, df_outlook = result
    dfs_soybean_oil.append(df_soybean_oil)
    dfs_current.append(df_current)
    dfs_next.append(df_next)
    dfs_outlook.append(df_outlook)

df_soybean_oil = pd.concat(dfs_soybean_oil, ignore_index=True)
df_soybean_oil_current = pd.concat(dfs_current, ignore_index=True, sort=False)
df_soybean_oil_next = pd.concat(dfs_next, ignore_index=True, sort=False)
df_soybean_oil_outlook = pd.concat(dfs_outlook, ignore_index=True, sort=False)

df_soybean_oil_current = df_soybean_oil_current.reset_index(drop=True)
df_soybean_oil_next = df_soybean_oil_next.reset_index(drop=True)
df_soybean_oil_outlook = df_soybean_oil_outlook.reset_index(drop=True)
df_soybean_oil = df_soybean_oil.reset_index(drop=True)

df_soybean_oil_current.to_excel(SOYBEAN_OIL_CURRENT)
df_soybean_oil_next.to_excel(SOYBEAN_OIL_NEXT)
df_soybean_oil_outlook.to_excel(SOYBEAN_OIL_OUTLOOK)
df_soybean_oil.to_excel(SOYBEAN_OIL)

# Logs
print(f"✅ df_soybean_oil created with {len(df_soybean_oil)} lines.")
print(f"✅ df_soybean_oil_current created with {len(df_soybean_oil_current)} lines.")
print(f"✅ df_soybean_oil_next created with {len(df_soybean_oil_next)} lines.")
print(f"✅ df_soybean_oil_outlook created with {len(df_soybean_oil_outlook)} lines.")
# Out:
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-09_wasde-05-09-2001_rice-revision.xls: Worksheet named 'Page 30' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-10_wasde-05-10-2001_wheat-revision.xls: Worksheet named 'Page 30' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-05-10_wasde-05-10-2002_world_grains_revision.xls: Worksheet named 'Page 30' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-11-12_wasde-11-12-2002_China_wheat_revision.xls: Worksheet named 'Page 30' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2003-07-11_wasde-07-11-2003_world_oilseed_revision.xls: Worksheet named 'Page 30' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2004-05-12_wasde-05-12-2004_world_coarse_grains_revision.xls: Worksheet named 'Page 30' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2008-05-09_wasde-05-09-2008_Historical_Dairy_revisions.xls: Worksheet named 'Page 30' not found
# ✅ df_soybean_oil created with 6239 lines.
# ✅ df_soybean_oil_current created with 179 lines.
# ✅ df_soybean_oil_next created with 179 lines.
# ✅ df_soybean_oil_outlook created with 179 lines.

# %% [markdown]
# 7. Processing soybean meal

# %%
files = list(WASDE_FOLDER.glob('*.xls'))

latest_file_by_date = {}
for file in files:
    basename = os.path.basename(file)
    report_date = basename.split('_')[0]
    latest_file_by_date[report_date] = file  


dfs_soybean_meal = []
dfs_current = []
dfs_next = []
dfs_outlook = []

for file in latest_file_by_date.values():
    result = process_soybean_meal(file)
    if result is None:
        continue

    df_soybean_meal, df_current, df_next, df_outlook = result
    dfs_soybean_meal.append(df_soybean_meal)
    dfs_current.append(df_current)
    dfs_next.append(df_next)
    dfs_outlook.append(df_outlook)

df_soybean_meal = pd.concat(dfs_soybean_meal, ignore_index=True)
df_soybean_meal_current = pd.concat(dfs_current, ignore_index=True, sort=False)
df_soybean_meal_next = pd.concat(dfs_next, ignore_index=True, sort=False)
df_soybean_meal_outlook = pd.concat(dfs_outlook, ignore_index=True, sort=False)

df_soybean_meal_current = df_soybean_meal_current.reset_index(drop=True)
df_soybean_meal_next = df_soybean_meal_next.reset_index(drop=True)
df_soybean_meal_outlook = df_soybean_meal_outlook.reset_index(drop=True)
df_soybean_meal = df_soybean_meal.reset_index(drop=True)

df_soybean_meal_current.to_excel(SOYBEAN_MEAL_CURRENT)
df_soybean_meal_next.to_excel(SOYBEAN_MEAL_NEXT)
df_soybean_meal_outlook.to_excel(SOYBEAN_MEAL_OUTLOOK)
df_soybean_meal.to_excel(SOYBEAN_MEAL)

# Logs
print(f"✅ df_soybean_meal created with {len(df_soybean_meal)} lines.")
print(f"✅ df_soybean_meal_current created with {len(df_soybean_meal_current)} lines.")
print(f"✅ df_soybean_meal_next created with {len(df_soybean_meal_next)} lines.")
print(f"✅ df_soybean_meal_outlook created with {len(df_soybean_meal_outlook)} lines.")
# Out:
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-09_wasde-05-09-2001_rice-revision.xls: Worksheet named 'Page 29' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2001-05-10_wasde-05-10-2001_wheat-revision.xls: Worksheet named 'Page 29' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-05-10_wasde-05-10-2002_world_grains_revision.xls: Worksheet named 'Page 29' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2002-11-12_wasde-11-12-2002_China_wheat_revision.xls: Worksheet named 'Page 29' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2003-07-11_wasde-07-11-2003_world_oilseed_revision.xls: Worksheet named 'Page 29' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2004-05-12_wasde-05-12-2004_world_coarse_grains_revision.xls: Worksheet named 'Page 29' not found
# ⚠️ Error reading C:\Users\d1eg0\Desktop\python\Prediction\sarimax\data\wasde_files\2008-05-09_wasde-05-09-2008_Historical_Dairy_revisions.xls: Worksheet named 'Page 29' not found
# ✅ df_soybean_meal created with 6074 lines.
# ✅ df_soybean_meal_current created with 179 lines.
# ✅ df_soybean_meal_next created with 179 lines.
# ✅ df_soybean_meal_outlook created with 179 lines.

# %% [markdown]
# 8. Concat of commodity data

# %%
df_commodity = pd.concat([df_wheat, df_corn, df_soybean, df_soybean_oil, df_soybean_meal], ignore_index=True)
df_commodity.to_excel(COMMODITY)
